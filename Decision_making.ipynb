# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutijadhav25-cell/Data_science_lab_SE_A_69/blob/main/Decision_making.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 10

if num > 0:
    print("The number is positive.")
else:
    print("The number is not positive (it's zero or negative).")
# Out:
# The number is positive.
