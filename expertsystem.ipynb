# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutijadhav25-cell/Data_science_lab_SE_A_69/blob/main/expertsystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temp = float(input("Enter body temperature: "))

if temp > 38:
    print("Diagnosis: High Fever")
elif temp >= 37:
    print("Diagnosis: Mild Fever")
else:
    print("Diagnosis: Normal Temperature")
# Out:
# Enter body temperature: 39
# Diagnosis: High Fever
