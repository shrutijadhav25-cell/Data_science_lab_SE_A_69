# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutijadhav25-cell/Data_science_lab_SE_A_69/blob/main/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_palindrome_number(number_str):
    return number_str == number_str[::-1]

user_input = input("Enter a number: ")


if is_palindrome_number(user_input):
  print(f"{user_input} is a palindrome number.")
else:
  print(f"{user_input} is not a palindrome number.")
# Out:
# Enter a number: 1001
# 1001 is a palindrome number.
